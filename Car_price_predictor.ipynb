# %% [markdown]
# # Task 1 :
# ### Installing Java, Spark3+ , and a compatible pyspark Python lib and making it work.

# %%
# Testing pyspark installation

import findspark
findspark.init()
findspark.find()
import pyspark
findspark.find()
# Out:
# 'C:\\spark-3.2.0-bin-hadoop3.2'

# %%
# Initiate spark context
from pyspark import SparkContext, SparkConf 
from pyspark.sql import SparkSession
conf = pyspark.SparkConf().setAppName('SparkApp').setMaster('local')
sc = pyspark.SparkContext(conf=conf)
spark =SparkSession(sc)

# %%
#Example Test code
numeric_val = sc.parallelize([1,2,3,4])
numeric_val.map(lambda x: x*x*x).collect()
# Out:
# [1, 8, 27, 64]

# %%
# Stop the spark session
sc.stop()

# %% [markdown]
# # Task 2
# ### Read "Car details v3.csv" data with spark

# %%
df = spark.read.option("header", "true").csv ('Car details v3.csv')

# %%
df.limit(10).toPandas()
# Out:
#                                    name  year selling_price km_driven    fuel  \
# 0                Maruti Swift Dzire VDI  2014        450000    145500  Diesel
# 1          Skoda Rapid 1.5 TDI Ambition  2014        370000    120000  Diesel
# 2              Honda City 2017-2020 EXi  2006        158000    140000  Petrol
# 3             Hyundai i20 Sportz Diesel  2010        225000    127000  Diesel
# 4                Maruti Swift VXI BSIII  2007        130000    120000  Petrol
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017        440000     45000  Petrol
# 6          Maruti Wagon R LXI DUO BSIII  2007         96000    175000     LPG
# 7                    Maruti 800 DX BSII  2001         45000      5000  Petrol
# 8                      Toyota Etios VXD  2011        350000     90000  Diesel
# 9  Ford Figo Diesel Celebration Edition  2013        200000    169000  Diesel
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
# 5  Individual       Manual   First Owner  20.14 kmpl  1197 CC   81.86 bhp
# 6  Individual       Manual   First Owner  17.3 km/kg  1061 CC    57.5 bhp
# 7  Individual       Manual  Second Owner   16.1 kmpl   796 CC      37 bhp
# 8  Individual       Manual   First Owner  23.59 kmpl  1364 CC    67.1 bhp
# 9  Individual       Manual   First Owner   20.0 kmpl  1399 CC    68.1 bhp
#
#                      torque seats
# 0            190Nm@ 2000rpm     5
# 1       250Nm@ 1500-2500rpm     5
# 2     12.7@ 2,700(kgm@ rpm)     5
# 3  22.4 kgm at 1750-2750rpm     5
# 4     11.5@ 4,500(kgm@ rpm)     5
# 5         113.75nm@ 4000rpm     5
# 6      7.8@ 4,500(kgm@ rpm)     5
# 7             59Nm@ 2500rpm     4
# 8       170Nm@ 1800-2400rpm     5
# 9            160Nm@ 2000rpm     5

# %% [markdown]
# # Task 3
# ### Creating a model to predict the selling price from the other variables using Sparks'mlib

# %%
spark = SparkSession.builder.getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-CRAL56H.mshome.net:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>SparkApp</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- selling_price: string (nullable = true)
#  |-- km_driven: string (nullable = true)
#  |-- fuel: string (nullable = true)
#  |-- seller_type: string (nullable = true)
#  |-- transmission: string (nullable = true)
#  |-- owner: string (nullable = true)
#  |-- mileage: string (nullable = true)
#  |-- engine: string (nullable = true)
#  |-- max_power: string (nullable = true)
#  |-- torque: string (nullable = true)
#  |-- seats: string (nullable = true)

# %% [markdown]
# All the columns are string type.
# The selling_price is our target and the remainder are our features we want to predict the target with.

# %%
df.show(2)
# Out:
# +--------------------+----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+-------------------+-----+
# |                name|year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|   mileage| engine| max_power|             torque|seats|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+-------------------+-----+
# |Maruti Swift Dzir...|2014|       450000|   145500|Diesel| Individual|      Manual| First Owner| 23.4 kmpl|1248 CC|    74 bhp|     190Nm@ 2000rpm|    5|
# |Skoda Rapid 1.5 T...|2014|       370000|   120000|Diesel| Individual|      Manual|Second Owner|21.14 kmpl|1498 CC|103.52 bhp|250Nm@ 1500-2500rpm|    5|
# +--------------------+----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+-------------------+-----+
# only showing top 2 rows

# %% [markdown]
# Let's select some columns to see how the dataframe look like.

# %%
df_show = df.select("year","selling_price","km_driven","fuel")

# %%
df_show.show(2)
# Out:
# +----+-------------+---------+------+
# |year|selling_price|km_driven|  fuel|
# +----+-------------+---------+------+
# |2014|       450000|   145500|Diesel|
# |2014|       370000|   120000|Diesel|
# +----+-------------+---------+------+
# only showing top 2 rows

# %% [markdown]
# ## Pre-processing the data

# %%
#droping the name column
df=df.drop("name")
df.show(5)
# Out:
# +----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+--------------------+-----+
# |year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|   mileage| engine| max_power|              torque|seats|
# +----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+--------------------+-----+
# |2014|       450000|   145500|Diesel| Individual|      Manual| First Owner| 23.4 kmpl|1248 CC|    74 bhp|      190Nm@ 2000rpm|    5|
# |2014|       370000|   120000|Diesel| Individual|      Manual|Second Owner|21.14 kmpl|1498 CC|103.52 bhp| 250Nm@ 1500-2500rpm|    5|
# |2006|       158000|   140000|Petrol| Individual|      Manual| Third Owner| 17.7 kmpl|1497 CC|    78 bhp|12.7@ 2,700(kgm@ ...|    5|
# |2010|       225000|   127000|Diesel| Individual|      Manual| First Owner| 23.0 kmpl|1396 CC|    90 bhp|22.4 kgm at 1750-...|    5|
# |2007|       130000|   120000|Petrol| Individual|      Manual| First Owner| 16.1 kmpl|1298 CC|  88.2 bhp|11.5@ 4,500(kgm@ ...|    5|
# +----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+--------------------+-----+
# only showing top 5 rows

# %%
df.describe()
# Out:
# DataFrame[summary: string, year: string, selling_price: string, km_driven: string, fuel: string, seller_type: string, transmission: string, owner: string, mileage: string, engine: string, max_power: string, torque: string, seats: string]

# %%
# df["year"].unique()
df.select('seller_type').distinct().collect()
# Out:
# [Row(seller_type='Individual'),
#  Row(seller_type='Dealer'),
#  Row(seller_type='Trustmark Dealer')]

# %%
df.select('fuel').distinct().collect()
# Out:
# [Row(fuel='Diesel'), Row(fuel='CNG'), Row(fuel='LPG'), Row(fuel='Petrol')]

# %%
df.select('transmission').distinct().collect()
# Out:
# [Row(transmission='Automatic'), Row(transmission='Manual')]

# %%
df.select('owner').distinct().collect()
# Out:
# [Row(owner='Third Owner'),
#  Row(owner='Fourth & Above Owner'),
#  Row(owner='Second Owner'),
#  Row(owner='First Owner'),
#  Row(owner='Test Drive Car')]

# %%
df.select('seats').distinct().collect()
# Out:
# [Row(seats='7'),
#  Row(seats='8'),
#  Row(seats=None),
#  Row(seats='5'),
#  Row(seats='6'),
#  Row(seats='9'),
#  Row(seats='10'),
#  Row(seats='4'),
#  Row(seats='14'),
#  Row(seats='2')]

# %%
df_re=df.select("mileage", "engine","max_power", "torque")
df_re.show(100)
# Out:
# +-----------+-------+-----------+--------------------+
# |    mileage| engine|  max_power|              torque|
# +-----------+-------+-----------+--------------------+
# |  23.4 kmpl|1248 CC|     74 bhp|      190Nm@ 2000rpm|
# | 21.14 kmpl|1498 CC| 103.52 bhp| 250Nm@ 1500-2500rpm|
# |  17.7 kmpl|1497 CC|     78 bhp|12.7@ 2,700(kgm@ ...|
# |  23.0 kmpl|1396 CC|     90 bhp|22.4 kgm at 1750-...|
# |  16.1 kmpl|1298 CC|   88.2 bhp|11.5@ 4,500(kgm@ ...|
# | 20.14 kmpl|1197 CC|  81.86 bhp|   113.75nm@ 4000rpm|
# | 17.3 km/kg|1061 CC|   57.5 bhp|7.8@ 4,500(kgm@ rpm)|
# |  16.1 kmpl| 796 CC|     37 bhp|       59Nm@ 2500rpm|
# | 23.59 kmpl|1364 CC|   67.1 bhp| 170Nm@ 1800-2400rpm|
# |  20.0 kmpl|1399 CC|   68.1 bhp|      160Nm@ 2000rpm|
# | 19.01 kmpl|1461 CC| 108.45 bhp|      248Nm@ 2250rpm|
# |  17.3 kmpl| 993 CC|     60 bhp|       78Nm@ 4500rpm|
# |  19.3 kmpl|1248 CC|   73.9 bhp|      190Nm@ 2000rpm|
# |       null|   null|       null|                null|
# |  18.9 kmpl|1061 CC|     67 bhp|       84Nm@ 3500rpm|
# | 18.15 kmpl|1198 CC|     82 bhp| 115Nm@ 3500-3600rpm|
# | 24.52 kmpl|1248 CC|   88.5 bhp|      200Nm@ 1750rpm|
# |  23.0 kmpl|1396 CC|     90 bhp|22.4 kgm at 1750-...|
# |  19.7 kmpl| 796 CC|   46.3 bhp|       62Nm@ 3000rpm|
# | 22.54 kmpl|1396 CC|  88.73 bhp|219.7Nm@ 1500-275...|
# |  21.0 kmpl|1461 CC|   64.1 bhp|      160Nm@ 2000rpm|
# |  25.5 kmpl|1498 CC|   98.6 bhp|      200Nm@ 1750rpm|
# | 26.59 kmpl|1248 CC|     74 bhp|      190Nm@ 2000rpm|
# |  21.5 kmpl|1248 CC|   88.8 bhp|      200Nm@ 1750rpm|
# |  20.3 kmpl|1199 CC|  83.81 bhp|      114Nm@ 3500rpm|
# |  21.4 kmpl|1197 CC|   83.1 bhp|      115Nm@ 4000rpm|
# |  24.7 kmpl| 796 CC|   47.3 bhp|       69Nm@ 3500rpm|
# |  18.2 kmpl|1248 CC|   73.8 bhp|    172.5Nm@ 1750rpm|
# |  18.9 kmpl|1061 CC|     67 bhp|       84Nm@ 3500rpm|
# |  16.8 kmpl| 796 CC|   34.2 bhp|       59Nm@ 2500rpm|
# |  24.3 kmpl|1248 CC|   88.5 bhp|      200Nm@ 1750rpm|
# |       null|   null|       null|                null|
# |  14.0 kmpl| 796 CC|     35 bhp|     6.1kgm@ 3000rpm|
# |  18.6 kmpl|1197 CC|  81.83 bhp|    114.7Nm@ 4000rpm|
# |  24.3 kmpl|1248 CC|   88.5 bhp|      200Nm@ 1750rpm|
# |33.44 km/kg| 796 CC|   40.3 bhp|       60Nm@ 3500rpm|
# | 23.95 kmpl| 998 CC|   67.1 bhp|       90Nm@ 3500rpm|
# |  17.0 kmpl|1591 CC|  121.3 bhp|      151Nm@ 4850rpm|
# | 20.63 kmpl|1198 CC|     67 bhp|      104Nm@ 4000rpm|
# | 13.93 kmpl|2179 CC| 138.03 bhp| 320Nm@ 1700-2700rpm|
# |  16.1 kmpl| 796 CC|     37 bhp|       59Nm@ 2500rpm|
# |  16.0 kmpl|1368 CC| 160.77 bhp| 250Nm@ 1750-2500rpm|
# |  17.8 kmpl|1497 CC|  117.3 bhp|      145Nm@ 4600rpm|
# |  16.8 kmpl|1497 CC|  116.3 bhp|      146Nm@ 4800rpm|
# |  18.5 kmpl|1197 CC|  83.14 bhp|      115Nm@ 4000rpm|
# |  24.3 kmpl|1248 CC|   88.5 bhp|      200Nm@ 1750rpm|
# | 23.95 kmpl| 998 CC|  67.05 bhp|       90Nm@ 3500rpm|
# | 12.55 kmpl|2982 CC|  168.5 bhp| 343Nm@ 1400-3400rpm|
# | 12.99 kmpl|2494 CC|    100 bhp| 200Nm@ 1400-3400rpm|
# |  14.8 kmpl|2143 CC|  120.7 bhp| 200Nm@ 1250-4000rpm|
# |  24.7 kmpl|1498 CC|  98.63 bhp|      200Nm@ 1750rpm|
# |  13.5 kmpl|2477 CC| 175.56 bhp| 400Nm@ 2000-2500rpm|
# |  26.0 kmpl|1498 CC|   98.6 bhp|      200Nm@ 1750rpm|
# | 20.65 kmpl|1462 CC| 103.25 bhp|      138Nm@ 4400rpm|
# |  27.3 kmpl|1498 CC|   98.6 bhp|      200Nm@ 1750rpm|
# | 11.36 kmpl|2755 CC|  171.5 bhp| 360Nm@ 1200-3400rpm|
# | 12.99 kmpl|2494 CC|  100.6 bhp| 200Nm@ 1200-3600rpm|
# | 17.68 kmpl|1968 CC| 174.33 bhp| 380Nm@ 1750-2500rpm|
# | 14.28 kmpl|1798 CC| 138.03 bhp|      173Nm@ 4000rpm|
# | 18.53 kmpl|1968 CC| 187.74 bhp| 400Nm@ 1750-3000rpm|
# | 14.84 kmpl|2143 CC|    170 bhp| 400Nm@ 1400-2800rpm|
# | 21.12 kmpl|1248 CC|   88.8 bhp| 200Nm@ 1750-3000rpm|
# | 20.36 kmpl|1197 CC|   78.9 bhp|    111.7Nm@ 4000rpm|
# | 21.27 kmpl|1396 CC|  88.76 bhp|219.6Nm@ 1500-275...|
# | 26.59 kmpl|1248 CC|     74 bhp|      190Nm@ 2000rpm|
# | 18.16 kmpl|1196 CC|   86.8 bhp|      112Nm@ 4000rpm|
# |  21.4 kmpl|1197 CC|   83.1 bhp|      115Nm@ 4000rpm|
# |  22.0 kmpl|1498 CC|108.495 bhp| 250Nm@ 1500-3000rpm|
# |  25.1 kmpl|1498 CC|   98.6 bhp|      200Nm@ 1750rpm|
# | 20.51 kmpl| 998 CC|     67 bhp|       90Nm@ 3500rpm|
# | 21.66 kmpl|1498 CC| 108.62 bhp| 250Nm@ 1500-3000rpm|
# |  24.3 kmpl|1248 CC|   88.5 bhp|      200Nm@ 1750rpm|
# |  24.3 kmpl|1248 CC|   88.5 bhp|      200Nm@ 1750rpm|
# | 20.36 kmpl|1197 CC|   78.9 bhp|    111.7Nm@ 4000rpm|
# |  25.2 kmpl|1248 CC|     74 bhp|      190Nm@ 2000rpm|
# | 12.55 kmpl|2982 CC|  168.5 bhp| 343Nm@ 1400-3400rpm|
# |  22.9 kmpl|1248 CC|     74 bhp|      190Nm@ 2000rpm|
# | 16.02 kmpl|1373 CC|   93.7 bhp|      130Nm@ 4000rpm|
# |       null|   null|       null|                null|
# | 20.54 kmpl|1598 CC|  103.6 bhp| 250Nm@ 1500-2500rpm|
# | 12.99 kmpl|2494 CC|  100.6 bhp| 200Nm@ 1200-3600rpm|
# | 22.77 kmpl|1498 CC|  98.59 bhp| 205Nm@ 1750-3250rpm|
# | 15.71 kmpl|1998 CC|    189 bhp| 280Nm@ 1350-4600rpm|
# |  23.1 kmpl| 998 CC|  67.04 bhp|       90Nm@ 3500rpm|
# | 19.02 kmpl|1198 CC|  67.05 bhp|      104Nm@ 4000rpm|
# |  24.7 kmpl| 796 CC|   47.3 bhp|       69Nm@ 3500rpm|
# |  24.7 kmpl| 796 CC|   47.3 bhp|       69Nm@ 3500rpm|
# |       null|   null|       null|                null|
# | 19.81 kmpl|1086 CC|  68.05 bhp|    99.04Nm@ 4500rpm|
# |  14.0 kmpl| 796 CC|     35 bhp|     6.1kgm@ 3000rpm|
# | 26.2 km/kg| 998 CC|   58.2 bhp|       77Nm@ 3500rpm|
# | 16.47 kmpl|1198 CC|     74 bhp|      110Nm@ 3750rpm|
# | 19.81 kmpl|1086 CC|  68.05 bhp|    99.04Nm@ 4500rpm|
# | 15.04 kmpl|1598 CC|  103.6 bhp|      153Nm@ 3800rpm|
# |  18.2 kmpl| 998 CC|   67.1 bhp|       90Nm@ 3500rpm|
# |  18.5 kmpl|1197 CC|  82.85 bhp|    113.7Nm@ 4000rpm|
# | 26.59 kmpl|1248 CC|     74 bhp|      190Nm@ 2000rpm|
# |  19.1 kmpl|1197 CC|     82 bhp|      114Nm@ 4000rpm|
# |  19.7 kmpl| 796 CC|   46.3 bhp|       62Nm@ 3000rpm|
# | 22.54 kmpl|1396 CC|  88.73 bhp|219.7Nm@ 1500-275...|
# +-----------+-------+-----------+--------------------+
# only showing top 100 rows

# %%
df=df.drop("torque")
df.show(100)
# Out:
# +----+-------------+---------+------+-----------+------------+------------+-----------+-------+-----------+-----+
# |year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|    mileage| engine|  max_power|seats|
# +----+-------------+---------+------+-----------+------------+------------+-----------+-------+-----------+-----+
# |2014|       450000|   145500|Diesel| Individual|      Manual| First Owner|  23.4 kmpl|1248 CC|     74 bhp|    5|
# |2014|       370000|   120000|Diesel| Individual|      Manual|Second Owner| 21.14 kmpl|1498 CC| 103.52 bhp|    5|
# |2006|       158000|   140000|Petrol| Individual|      Manual| Third Owner|  17.7 kmpl|1497 CC|     78 bhp|    5|
# |2010|       225000|   127000|Diesel| Individual|      Manual| First Owner|  23.0 kmpl|1396 CC|     90 bhp|    5|
# |2007|       130000|   120000|Petrol| Individual|      Manual| First Owner|  16.1 kmpl|1298 CC|   88.2 bhp|    5|
# |2017|       440000|    45000|Petrol| Individual|      Manual| First Owner| 20.14 kmpl|1197 CC|  81.86 bhp|    5|
# |2007|        96000|   175000|   LPG| Individual|      Manual| First Owner| 17.3 km/kg|1061 CC|   57.5 bhp|    5|
# |2001|        45000|     5000|Petrol| Individual|      Manual|Second Owner|  16.1 kmpl| 796 CC|     37 bhp|    4|
# |2011|       350000|    90000|Diesel| Individual|      Manual| First Owner| 23.59 kmpl|1364 CC|   67.1 bhp|    5|
# |2013|       200000|   169000|Diesel| Individual|      Manual| First Owner|  20.0 kmpl|1399 CC|   68.1 bhp|    5|
# |2014|       500000|    68000|Diesel| Individual|      Manual|Second Owner| 19.01 kmpl|1461 CC| 108.45 bhp|    5|
# |2005|        92000|   100000|Petrol| Individual|      Manual|Second Owner|  17.3 kmpl| 993 CC|     60 bhp|    5|
# |2009|       280000|   140000|Diesel| Individual|      Manual|Second Owner|  19.3 kmpl|1248 CC|   73.9 bhp|    5|
# |2007|       200000|    80000|Petrol| Individual|      Manual|Second Owner|       null|   null|       null| null|
# |2009|       180000|    90000|Petrol| Individual|      Manual|Second Owner|  18.9 kmpl|1061 CC|     67 bhp|    5|
# |2016|       400000|    40000|Petrol| Individual|      Manual| First Owner| 18.15 kmpl|1198 CC|     82 bhp|    5|
# |2016|       778000|    70000|Diesel| Individual|      Manual|Second Owner| 24.52 kmpl|1248 CC|   88.5 bhp|    7|
# |2012|       500000|    53000|Diesel| Individual|      Manual|Second Owner|  23.0 kmpl|1396 CC|     90 bhp|    5|
# |2002|       150000|    80000|Petrol| Individual|      Manual|Second Owner|  19.7 kmpl| 796 CC|   46.3 bhp|    5|
# |2016|       680000|   100000|Diesel| Individual|      Manual| First Owner| 22.54 kmpl|1396 CC|  88.73 bhp|    5|
# |2011|       174000|   100000|Diesel| Individual|      Manual|Second Owner|  21.0 kmpl|1461 CC|   64.1 bhp|    5|
# |2017|       950000|    50000|Diesel| Individual|      Manual| First Owner|  25.5 kmpl|1498 CC|   98.6 bhp|    5|
# |2015|       525000|    40000|Diesel| Individual|      Manual| First Owner| 26.59 kmpl|1248 CC|     74 bhp|    5|
# |2012|       600000|    72000|Diesel| Individual|      Manual| First Owner|  21.5 kmpl|1248 CC|   88.8 bhp|    5|
# |2018|       500000|    35000|Petrol| Individual|      Manual| First Owner|  20.3 kmpl|1199 CC|  83.81 bhp|    5|
# |2016|       575000|    45000|Petrol| Individual|      Manual| First Owner|  21.4 kmpl|1197 CC|   83.1 bhp|    5|
# |2017|       275000|    28000|Petrol| Individual|      Manual| First Owner|  24.7 kmpl| 796 CC|   47.3 bhp|    5|
# |2013|       300000|    70000|Diesel| Individual|      Manual| First Owner|  18.2 kmpl|1248 CC|   73.8 bhp|    7|
# |2009|       220000|   120000|Petrol| Individual|      Manual| First Owner|  18.9 kmpl|1061 CC|     67 bhp|    5|
# |2018|       254999|    25000|Petrol| Individual|      Manual| First Owner|  16.8 kmpl| 796 CC|   34.2 bhp|    8|
# |2017|       670000|    70000|Diesel| Individual|      Manual| First Owner|  24.3 kmpl|1248 CC|   88.5 bhp|    5|
# |2003|        70000|    50000|Petrol| Individual|      Manual|Second Owner|       null|   null|       null| null|
# |2012|       150000|    35000|Petrol| Individual|      Manual|Second Owner|  14.0 kmpl| 796 CC|     35 bhp|    5|
# |2018|       730000|     2388|Petrol| Individual|      Manual| First Owner|  18.6 kmpl|1197 CC|  81.83 bhp|    5|
# |2017|       650000|    16200|Diesel| Individual|      Manual| First Owner|  24.3 kmpl|1248 CC|   88.5 bhp|    5|
# |2019|       330000|    10000|   CNG| Individual|      Manual|Second Owner|33.44 km/kg| 796 CC|   40.3 bhp|    4|
# |2019|       366000|    15000|Petrol| Individual|      Manual| First Owner| 23.95 kmpl| 998 CC|   67.1 bhp|    5|
# |2019|      1149000|     5000|Petrol| Individual|      Manual| First Owner|  17.0 kmpl|1591 CC|  121.3 bhp|    5|
# |2016|       150000|    42000|Petrol| Individual|      Manual| First Owner| 20.63 kmpl|1198 CC|     67 bhp|    5|
# |2011|       425000|    60000|Diesel| Individual|      Manual|Second Owner| 13.93 kmpl|2179 CC| 138.03 bhp|    7|
# |2012|       150000|    76000|Petrol| Individual|      Manual| First Owner|  16.1 kmpl| 796 CC|     37 bhp|    4|
# |2019|      2100000|     5000|Petrol| Individual|   Automatic| First Owner|  16.0 kmpl|1368 CC| 160.77 bhp|    5|
# |2018|       925000|    28900|Petrol|     Dealer|      Manual| First Owner|  17.8 kmpl|1497 CC|  117.3 bhp|    5|
# |2013|       425000|    86300|Petrol|     Dealer|      Manual| First Owner|  16.8 kmpl|1497 CC|  116.3 bhp|    5|
# |2018|       675000|    23300|Petrol|     Dealer|   Automatic| First Owner|  18.5 kmpl|1197 CC|  83.14 bhp|    5|
# |2018|       819999|    32600|Diesel|     Dealer|      Manual| First Owner|  24.3 kmpl|1248 CC|   88.5 bhp|    5|
# |2018|       390000|    10300|Petrol|     Dealer|      Manual| First Owner| 23.95 kmpl| 998 CC|  67.05 bhp|    5|
# |2014|      1500000|    77000|Diesel|     Dealer|      Manual| First Owner| 12.55 kmpl|2982 CC|  168.5 bhp|    7|
# |2013|       700000|    99000|Diesel|     Dealer|      Manual| First Owner| 12.99 kmpl|2494 CC|    100 bhp|    7|
# |2014|      1450000|    27800|Diesel|     Dealer|   Automatic|Second Owner|  14.8 kmpl|2143 CC|  120.7 bhp|    5|
# |2015|       425000|    49800|Diesel|     Dealer|      Manual| First Owner|  24.7 kmpl|1498 CC|  98.63 bhp|    5|
# |2013|      1090000|   151000|Diesel|     Dealer|      Manual| First Owner|  13.5 kmpl|2477 CC| 175.56 bhp|    7|
# |2015|       600000|    54700|Diesel|     Dealer|      Manual| First Owner|  26.0 kmpl|1498 CC|   98.6 bhp|    5|
# |2018|       850000|    64000|Petrol|     Dealer|      Manual| First Owner| 20.65 kmpl|1462 CC| 103.25 bhp|    5|
# |2015|       525000|    63000|Diesel|     Dealer|      Manual| First Owner|  27.3 kmpl|1498 CC|   98.6 bhp|    5|
# |2016|      1650000|   127700|Diesel|     Dealer|   Automatic|Second Owner| 11.36 kmpl|2755 CC|  171.5 bhp|    7|
# |2016|       950000|    99000|Diesel|     Dealer|      Manual| First Owner| 12.99 kmpl|2494 CC|  100.6 bhp|    7|
# |2013|      1750000|    33900|Diesel|     Dealer|   Automatic|Second Owner| 17.68 kmpl|1968 CC| 174.33 bhp|    5|
# |2018|      1590000|    25000|Petrol|     Dealer|   Automatic| First Owner| 14.28 kmpl|1798 CC| 138.03 bhp|    5|
# |2013|      1689999|    50000|Diesel|     Dealer|   Automatic| First Owner| 18.53 kmpl|1968 CC| 187.74 bhp|    5|
# |2013|      1425000|    59000|Diesel|     Dealer|   Automatic| First Owner| 14.84 kmpl|2143 CC|    170 bhp|    5|
# |2011|       265000|   120000|Diesel| Individual|      Manual| First Owner| 21.12 kmpl|1248 CC|   88.8 bhp|    5|
# |2011|       190000|   110000|Petrol| Individual|      Manual| Third Owner| 20.36 kmpl|1197 CC|   78.9 bhp|    5|
# |2013|       425000|    60000|Diesel| Individual|      Manual| First Owner| 21.27 kmpl|1396 CC|  88.76 bhp|    5|
# |2015|       630000|   147000|Diesel| Individual|      Manual|Second Owner| 26.59 kmpl|1248 CC|     74 bhp|    5|
# |2017|       600000|    25000|Petrol| Individual|      Manual| Third Owner| 18.16 kmpl|1196 CC|   86.8 bhp|    5|
# |2019|       650000|    30000|Petrol| Individual|      Manual| First Owner|  21.4 kmpl|1197 CC|   83.1 bhp|    5|
# |2016|       540000|    40000|Diesel| Individual|      Manual| First Owner|  22.0 kmpl|1498 CC|108.495 bhp|    5|
# |2015|       630000|   135000|Diesel| Individual|      Manual| First Owner|  25.1 kmpl|1498 CC|   98.6 bhp|    5|
# |2018|       448000|    30000|Petrol| Individual|   Automatic| First Owner| 20.51 kmpl| 998 CC|     67 bhp|    5|
# |2017|       500000|    80000|Diesel| Individual|      Manual| First Owner| 21.66 kmpl|1498 CC| 108.62 bhp|    5|
# |2016|       745000|    70000|Diesel| Individual|      Manual| First Owner|  24.3 kmpl|1248 CC|   88.5 bhp|    5|
# |2019|      1025000|     9850|Diesel| Individual|   Automatic| First Owner|  24.3 kmpl|1248 CC|   88.5 bhp|    5|
# |2011|       235000|    60000|Petrol| Individual|      Manual|Second Owner| 20.36 kmpl|1197 CC|   78.9 bhp|    5|
# |2016|       630000|    70000|Diesel| Individual|      Manual| First Owner|  25.2 kmpl|1248 CC|     74 bhp|    5|
# |2015|      1700000|    78000|Diesel| Individual|      Manual|Second Owner| 12.55 kmpl|2982 CC|  168.5 bhp|    7|
# |2013|       450000|   120000|Diesel| Individual|      Manual|Second Owner|  22.9 kmpl|1248 CC|     74 bhp|    5|
# |2012|       450000|   120000|Petrol| Individual|      Manual|Second Owner| 16.02 kmpl|1373 CC|   93.7 bhp|    7|
# |2003|        50000|    70000|Diesel| Individual|      Manual| First Owner|       null|   null|       null| null|
# |2013|       450000|   170000|Diesel| Individual|      Manual| First Owner| 20.54 kmpl|1598 CC|  103.6 bhp|    5|
# |2016|      1200000|   140000|Diesel| Individual|      Manual| First Owner| 12.99 kmpl|2494 CC|  100.6 bhp|    8|
# |2015|       610000|    90000|Diesel| Individual|      Manual| First Owner| 22.77 kmpl|1498 CC|  98.59 bhp|    5|
# |2016|      2500000|    30000|Petrol| Individual|   Automatic|Second Owner| 15.71 kmpl|1998 CC|    189 bhp|    5|
# |2017|       484999|    10000|Petrol|     Dealer|      Manual| First Owner|  23.1 kmpl| 998 CC|  67.04 bhp|    5|
# |2016|       275000|    49000|Petrol|     Dealer|      Manual| First Owner| 19.02 kmpl|1198 CC|  67.05 bhp|    5|
# |2016|       315000|    32000|Petrol|     Dealer|      Manual| First Owner|  24.7 kmpl| 796 CC|   47.3 bhp|    5|
# |2016|       275000|    38000|Petrol|     Dealer|      Manual| First Owner|  24.7 kmpl| 796 CC|   47.3 bhp|    5|
# |2015|       475000|    78000|Diesel|     Dealer|      Manual| First Owner|       null|   null|       null| null|
# |2012|       290000|    28000|Petrol|     Dealer|      Manual| First Owner| 19.81 kmpl|1086 CC|  68.05 bhp|    5|
# |2017|       280000|    32000|Petrol|     Dealer|      Manual| First Owner|  14.0 kmpl| 796 CC|     35 bhp|    5|
# |2010|       225000|    44000|   LPG|     Dealer|      Manual| First Owner| 26.2 km/kg| 998 CC|   58.2 bhp|    5|
# |2015|       455000|    42000|Petrol|     Dealer|      Manual| First Owner| 16.47 kmpl|1198 CC|     74 bhp|    5|
# |2015|       351000|    45000|Petrol|     Dealer|      Manual|Second Owner| 19.81 kmpl|1086 CC|  68.05 bhp|    5|
# |2012|       535000|    12000|Petrol|     Dealer|      Manual|Second Owner| 15.04 kmpl|1598 CC|  103.6 bhp|    5|
# |2009|       175000|    55500|Petrol|     Dealer|      Manual| First Owner|  18.2 kmpl| 998 CC|   67.1 bhp|    5|
# |2013|       525000|    61500|Petrol|     Dealer|      Manual| First Owner|  18.5 kmpl|1197 CC|  82.85 bhp|    5|
# |2016|       600000|   150000|Diesel| Individual|      Manual| First Owner| 26.59 kmpl|1248 CC|     74 bhp|    5|
# |2016|       565000|    72000|Petrol|     Dealer|   Automatic| First Owner|  19.1 kmpl|1197 CC|     82 bhp|    5|
# |2008|       120000|    68000|Petrol|     Dealer|      Manual| Third Owner|  19.7 kmpl| 796 CC|   46.3 bhp|    5|
# |2017|       725000|   110000|Diesel| Individual|      Manual| First Owner| 22.54 kmpl|1396 CC|  88.73 bhp|    5|
# +----+-------------+---------+------+-----------+------------+------------+-----------+-------+-----------+-----+
# only showing top 100 rows

# %% [markdown]
# ### removing units from mileage, engine and max_power columns

# %% [markdown]
# #### counting null value in the dataframe

# %%
from pyspark.sql.functions import col,sum
df.select(*(sum(col(c).isNull().cast("int")).alias(c) for c in df.columns)).show()
# Out:
# +----+-------------+---------+----+-----------+------------+-----+-------+------+---------+-----+
# |year|selling_price|km_driven|fuel|seller_type|transmission|owner|mileage|engine|max_power|seats|
# +----+-------------+---------+----+-----------+------------+-----+-------+------+---------+-----+
# |   0|            0|        0|   0|          0|           0|    0|    221|   221|      215|  221|
# +----+-------------+---------+----+-----------+------------+-----+-------+------+---------+-----+

# %% [markdown]
# we have at least 200 null values in the columns: mileage, engine , max_power, torque  and seats

# %% [markdown]
# ### replacing the null value by their corresponding means

# %%
from pyspark.sql.functions import split, col
df2 = df.select(split(col("mileage"),",").alias("NameArray")).drop("mileage")
df2.show(5)
# Out:
# +------------+
# |   NameArray|
# +------------+
# | [23.4 kmpl]|
# |[21.14 kmpl]|
# | [17.7 kmpl]|
# | [23.0 kmpl]|
# | [16.1 kmpl]|
# +------------+
# only showing top 5 rows

# %%
df2.printSchema()
# Out:
# root
#  |-- NameArray: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
from pyspark.sql.functions import explode
#df3=df2.select(explode(df2.NameArray.cast("int")))
#df4=df2.withColumn("NameArray",df2.NameArray.cast('int'))
from pyspark.sql.functions import regexp_extract
from pyspark.sql.functions import regexp_replace
from pyspark.sql.functions import lit
#df5= df.withColumn("milage", regexp_replace("milage" , lit("lbs"), lit("")))
#df5.show(5)
#df9=df.select(regexp_extract(col('mileage'),'str', r'(\d+) (\D+)', 1).alias('d')).collect()

#df7=df.select("milage")
df6= df.withColumn("mileage_clean", regexp_extract("mileage", "\\d+", 0))
df6.show(10)
# Out:
# +----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+--------------------+-----+-------------+
# |year|selling_price|km_driven|  fuel|seller_type|transmission|       owner|   mileage| engine| max_power|              torque|seats|mileage_clean|
# +----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+--------------------+-----+-------------+
# |2014|       450000|   145500|Diesel| Individual|      Manual| First Owner| 23.4 kmpl|1248 CC|    74 bhp|      190Nm@ 2000rpm|    5|           23|
# |2014|       370000|   120000|Diesel| Individual|      Manual|Second Owner|21.14 kmpl|1498 CC|103.52 bhp| 250Nm@ 1500-2500rpm|    5|           21|
# |2006|       158000|   140000|Petrol| Individual|      Manual| Third Owner| 17.7 kmpl|1497 CC|    78 bhp|12.7@ 2,700(kgm@ ...|    5|           17|
# |2010|       225000|   127000|Diesel| Individual|      Manual| First Owner| 23.0 kmpl|1396 CC|    90 bhp|22.4 kgm at 1750-...|    5|           23|
# |2007|       130000|   120000|Petrol| Individual|      Manual| First Owner| 16.1 kmpl|1298 CC|  88.2 bhp|11.5@ 4,500(kgm@ ...|    5|           16|
# |2017|       440000|    45000|Petrol| Individual|      Manual| First Owner|20.14 kmpl|1197 CC| 81.86 bhp|   113.75nm@ 4000rpm|    5|           20|
# |2007|        96000|   175000|   LPG| Individual|      Manual| First Owner|17.3 km/kg|1061 CC|  57.5 bhp|7.8@ 4,500(kgm@ rpm)|    5|           17|
# |2001|        45000|     5000|Petrol| Individual|      Manual|Second Owner| 16.1 kmpl| 796 CC|    37 bhp|       59Nm@ 2500rpm|    4|           16|
# |2011|       350000|    90000|Diesel| Individual|      Manual| First Owner|23.59 kmpl|1364 CC|  67.1 bhp| 170Nm@ 1800-2400rpm|    5|           23|
# |2013|       200000|   169000|Diesel| Individual|      Manual| First Owner| 20.0 kmpl|1399 CC|  68.1 bhp|      160Nm@ 2000rpm|    5|           20|
# +----+-------------+---------+------+-----------+------------+------------+----------+-------+----------+--------------------+-----+-------------+
# only showing top 10 rows

# %%
df_show = df.select("mileage")
df_show.show(10)
# Out:
# +----------+
# |   mileage|
# +----------+
# | 23.4 kmpl|
# |21.14 kmpl|
# | 17.7 kmpl|
# | 23.0 kmpl|
# | 16.1 kmpl|
# |20.14 kmpl|
# |17.3 km/kg|
# | 16.1 kmpl|
# |23.59 kmpl|
# | 20.0 kmpl|
# +----------+
# only showing top 10 rows

# %%
df6= df_show.withColumn("mileage_clean", regexp_extract("mileage", "[+-]?([0-9]*[.])?[0-9]+", 0)).drop('mileage')
df6.show(10)
# Out:
# +-------------+
# |mileage_clean|
# +-------------+
# |         23.4|
# |        21.14|
# |         17.7|
# |         23.0|
# |         16.1|
# |        20.14|
# |         17.3|
# |         16.1|
# |        23.59|
# |         20.0|
# +-------------+
# only showing top 10 rows

# %%
df3.show(5)
# Out:
# +----------+
# |       col|
# +----------+
# | 23.4 kmpl|
# |21.14 kmpl|
# | 17.7 kmpl|
# | 23.0 kmpl|
# | 16.1 kmpl|
# +----------+
# only showing top 5 rows

# %%
# !pip install org.apache.spark.ml.feature
import org.apache.spark.sql.functions.col
import org.apache.spark.sql.types.IntegerType

df.withColumn("year",col("year").cast("int"))
# Out:
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement org.apache.spark.ml.feature (from versions: none)
# ERROR: No matching distribution found for org.apache.spark.ml.feature
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda\lib\site-packages)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21980/3087258227.py in <module>
#       1 get_ipython().system('pip install org.apache.spark.ml.feature')
# ----> 2 import org.apache.spark.sql.functions.col
#       3 import org.apache.spark.sql.types.IntegerType
#       4
#       5 df.withColumn("year",col("year").cast("int"))
#
# ModuleNotFoundError: No module named 'org'

# %%
# creating a age column
## Casting to 
df['age']=df[2021-df['year'].astype(int)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21980/421972639.py in <module>
#       1 # creating a age column
#       2 ## Casting to
# ----> 3 df['age']=df[2021-df['year'].astype(int)]
#
# C:\spark-3.2.0-bin-hadoop3.2\python\pyspark\sql\column.py in cast(self, dataType)
#     779             jc = self._jc.cast(jdt)
#     780         else:
# --> 781             raise TypeError("unexpected type: %s" % type(dataType))
#     782         return Column(jc)
#     783
#
# TypeError: unexpected type: <class 'type'>

# %%
help(spark.read..option("header", "true").csv())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21980/600765475.py in <module>
# ----> 1 help(spark.read.csv())
#
# TypeError: csv() missing 1 required positional argument: 'path'
